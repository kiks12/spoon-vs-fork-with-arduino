# %%
import tensorflow as tf
import pathlib
import PIL
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.python.tools import freeze_graph
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# %% [markdown]
# ## See and test dataset

# %%
DATA_SET_DIR = './dataset/'

# %%
data_dir = pathlib.Path(DATA_SET_DIR)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 392

# %%
spoons = list(data_dir.glob('spoon/*'))
forks = list(data_dir.glob('fork/*'))
neither = list(data_dir.glob('neither/*'))

PIL.Image.open(spoons[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x290>

# %%
PIL.Image.open(forks[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %%
PIL.Image.open(neither[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# ## Load Dataset with Keras

# %%
image_height = 250
image_width = 250
batch_size = 64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(image_height, image_width),
  batch_size=batch_size)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(image_height, image_width),
  batch_size=batch_size)
# Out:
# Found 435 files belonging to 3 classes.
# Using 348 files for training.
# Found 435 files belonging to 3 classes.
# Using 87 files for validation.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['fork', 'neither', 'spoon']

# %% [markdown]
# ## Preprocess Dataset

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 2022-09-17 21:13:37.489992: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 0.0 1.0

# %% [markdown]
# ## Create Model

# %%
num_classes = len(class_names)

# %%
data_augmentation = tf.keras.models.Sequential(
  [
    tf.keras.layers.RandomFlip("horizontal",
                      input_shape=(image_height,
                                  image_width,
                                  3)),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
  ]
)

# %%
model = tf.keras.models.Sequential([
    data_augmentation,
    tf.keras.layers.Rescaling(1./255, input_shape=(image_height, image_width, 3)),
    tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 250, 250, 3)       0
#
#  rescaling_5 (Rescaling)     (None, 250, 250, 3)       0
#
#  conv2d_8 (Conv2D)           (None, 250, 250, 8)       224
#
#  max_pooling2d_8 (MaxPooling  (None, 125, 125, 8)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 125, 125, 16)      1168
#
#  max_pooling2d_9 (MaxPooling  (None, 62, 62, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 62, 62, 32)        4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 31, 31, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 31, 31, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 15, 15, 64)        0
#
#  flatten_2 (Flatten)         (None, 14400)             0
#
#  dense_4 (Dense)             (None, 128)               1843328
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1,868,243
# Trainable params: 1,868,243
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 2022-09-17 21:13:48.676931: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - ETA: 0s - loss: 0.9898 - accuracy: 0.3678
# 2022-09-17 21:14:03.020081: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-09-17 21:14:03.083749: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 6/6 [==============================] - 17s 2s/step - loss: 0.9898 - accuracy: 0.3678 - val_loss: 0.8858 - val_accuracy: 0.4598
# Epoch 2/10
# 6/6 [==============================] - 12s 2s/step - loss: 0.8251 - accuracy: 0.5661 - val_loss: 0.7287 - val_accuracy: 0.5517
# Epoch 3/10
# 6/6 [==============================] - 13s 2s/step - loss: 0.6674 - accuracy: 0.6523 - val_loss: 0.7711 - val_accuracy: 0.5977
# Epoch 4/10
# 6/6 [==============================] - 15s 2s/step - loss: 0.6146 - accuracy: 0.6753 - val_loss: 0.6896 - val_accuracy: 0.5977
# Epoch 5/10
# 6/6 [==============================] - 14s 2s/step - loss: 0.5612 - accuracy: 0.6983 - val_loss: 0.6998 - val_accuracy: 0.5632
# Epoch 6/10
# 6/6 [==============================] - 17s 3s/step - loss: 0.5384 - accuracy: 0.6925 - val_loss: 0.6073 - val_accuracy: 0.5747
# Epoch 7/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.5067 - accuracy: 0.7356 - val_loss: 0.7863 - val_accuracy: 0.5977
# Epoch 8/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.4162 - accuracy: 0.8075 - val_loss: 0.7340 - val_accuracy: 0.6552
# Epoch 9/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.3982 - accuracy: 0.8161 - val_loss: 0.6958 - val_accuracy: 0.6552
# Epoch 10/10
# 6/6 [==============================] - 16s 3s/step - loss: 0.3595 - accuracy: 0.8103 - val_loss: 0.8299 - val_accuracy: 0.5862

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Save Model as h5 or pb

# %%
model.save('model1.4.h5')
#model.save('model1.1.pb')

# %% [markdown]
# ## Save Model as Frozen Graph

# %%
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))

# %%
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()
# Out:
# 2022-09-17 15:38:26.418889: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2022-09-17 15:38:26.419118: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2022-09-17 15:38:26.419835: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-09-17 15:38:26.419911: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Export frozen graph
with tf.io.gfile.GFile('frozen_graph.pb', 'wb') as f:
    f.write(graph_def.SerializeToString())
